# %%
# %load_ext autoreload
# %autoreload 2

import cv2

from tests.repeatability import run_test, generate_plots
from utils import get_files_from_string

# %%
files = sorted(get_files_from_string('bark'))

df = run_test(files, True, 10)
# Out:
# Running test Agast
# Running test AKAZE
# Running test BRISK
# Running test Fast
# Running test GFTT
# Running test KAZE
# Running test MSER
# Running test ORB
# Running test Harris
# Running test SIFT
# Running test SURF
# Running test Star

# %%
generate_plots(df)
